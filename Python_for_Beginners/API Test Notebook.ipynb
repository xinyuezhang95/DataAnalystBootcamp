# %% [markdown]
# API: Application Program Interface; basically acts as the intermediary between two applications that want to talk to each other
#
# API is between the client (sending the requests) & the server

# %%
# how to use an API
# crypto: coinmarketcap.com

# API documentation
# This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' # this and the key below need to be changed
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-05-09T02:59:45.174Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 91, 'name': 'pyzyxwnq5sm', 'symbol': '6hukxv5ncki', 'slug': 'fyrmc0yxm7', 'cmc_rank': 9939, 'num_market_pairs': 848, 'circulating_supply': 8151, 'total_supply': 3919, 'max_supply': 3728, 'infinite_supply': None, 'last_updated': '2023-05-09T02:59:45.174Z', 'date_added': '2023-05-09T02:59:45.174Z', 'tags': ['gdml4xn83ha', 'qo4md4k451s', 'ykuka0hmgge', 'twttjwysq', 't8308vpiwph', 'cos6ccvw3dl', 'i4onnx7t0q', 'vn0ssbdknof', 'xjsusepx4h', '4odey9pglsm'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.2654631790442161, 'volume_24h': 3490, 'volume_change_24h': 0.4560189759936928, 'percent_change_1h': 0.717438173598008, 'percent_change_24h': 0.5019553022428538, 'percent_change_7d': 0.4416069119017616, 'market_cap': 0.8901270713288691, 'market_cap_dominance': 57
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None) # shows all columns without ...

# %%
pd.json_normalize(data)
# Out:
#                                                 data  \
# 0  [{'id': 91, 'name': 'pyzyxwnq5sm', 'symbol': '...
#
#            status.timestamp  status.error_code status.error_message  \
# 0  2023-05-09T02:59:45.174Z                  0                 None
#
#    status.elapsed  status.credit_count status.notice
# 0               1                    1          None

# %%
pd.json_normalize(data['status'])
# Out:
#                   timestamp  error_code error_message  elapsed  credit_count  \
# 0  2023-05-09T02:59:45.174Z           0          None        1             1
#
#   notice
# 0   None

# %%
pd.json_normalize(data['data'])
# Out:
#      id         name        symbol         slug  cmc_rank  num_market_pairs  \
# 0    91  pyzyxwnq5sm   6hukxv5ncki   fyrmc0yxm7      9939               848
# 1  6638  zrs87ktxf7c   fnw5pbhxc7s  9512psejheo      2078              7364
# 2  8721  wbt19h8gs1q   5qtxquw00mh  44aqc1ddkpa      8110              5527
# 3  9770  y7mkmavr5rr  0osi8zkb4c0p  mnj35g8pz6q       501              8475
# 4  4526  pkv0woupr5h    evizxlvhyi   s5zusw94if      4388              8316
# 5   329  358qip6qw3o    yckpbiupge  libsjw872rs      3402              8334
# 6  3403   vpdd2h4rqx   6h76sknscpw   z2mb8z9a5e       555              1086
# 7  2895  q1yd9qb8zua   usw8qhi8q3h   x78zn3l87o      7732              1448
# 8  8319  3f7g7qc30xc  0mezbmuoghwo   siftqs2utd       128              9456
# 9  4718  3jrlbrdxpiu   8mtm7l1idat  exbivl3i6sa      3568              8238
#
#    circulating_supply  total_supply  max_supply infinite_supply  \
# 0                8151          3919        3728            None
# ...
